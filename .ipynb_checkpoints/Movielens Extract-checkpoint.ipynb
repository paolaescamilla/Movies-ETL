# %%
import pandas as pd

# %%
kaggle_metadata=pd.read_csv('movies_metadata.csv', low_memory=False)
ratings=pd.read_csv('ratings.csv')

# %%
kaggle_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection budget  \
# 17871  False                   NaN      0
# 26314  False                   NaN      0
# 3960   False                   NaN      0
# 4960   False                   NaN      0
# 10862  False                   NaN      0
#
#                                                   genres homepage      id  \
# 17871                                                 []      NaN   41822
# 26314  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN  122192
# 3960   [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN   11028
# 4960   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...      NaN   19562
# 10862                [{'id': 99, 'name': 'Documentary'}]      NaN   35555
#
#          imdb_id original_language      original_title  \
# 17871  tt0099927                cn                客途秋恨
# 26314  tt1946298                fr         Le Guetteur
# 3960   tt0092654                en        The Big Easy
# 4960   tt0070354                fr       Le Magnifique
# 10862  tt0436864                en  Unknown White Male
#
#                                                 overview  ... release_date  \
# 17871  Set in the early 1970s, it tells the story of ...  ...   1990-04-27
# 26314  A major police operation to take down a notori...  ...   2012-09-05
# 3960   Remy McSwain is a New Orleans police lieutenan...  ...   1986-11-27
# 4960   François Merlin (Belmondo) is a Jean Bruce typ...  ...   1973-11-23
# 10862  The true story of Doug Bruce who woke up on Co...  ...   2005-06-01
#
#       revenue runtime                                   spoken_languages  \
# 17871     0.0   100.0  [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'i...
# 26314     0.0    89.0          [{'iso_639_1': 'fr', 'name': 'Français'}]
# 3960      0.0   102.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4960      0.0    95.0  [{'iso_639_1': 'sq', 'name': 'shqip'}, {'iso_6...
# 10862     0.0    88.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 17871   Rumored                                                NaN
# 26314  Released                                                NaN
# 3960   Released  A cop and a lady lawyer caught in an explosive...
# 4960   Released                                                NaN
# 10862  Released                                                NaN
#
#                      title  video vote_average vote_count
# 17871    Song of the Exile  False          5.0        1.0
# 26314          The Lookout  False          5.5       34.0
# 3960          The Big Easy  False          6.2       52.0
# 4960   The Magnificent One  False          7.2       33.0
# 10862   Unknown White Male  False          6.5        5.0
#
# [5 rows x 24 columns]

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 3234062    33631     1284     5.0   939030853
# 9294990    95957    31696     3.0  1238198101
# 14506119  150781    80363     2.0  1392902538
# 8826361    90994      926     5.0  1338004806
# 12188916  126438      597     5.0   833440166
